# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
housing=pd.read_csv("Housing.csv", index_col=False)
housing.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
housing.shape
# Out:
# (5000, 7)

# %%
sns.jointplot(x=housing['Avg. Area Number of Rooms'], y=housing['Price'], data=housing, kind='reg')

# %%
x_train, x_test, y_train, y_test = train_test_split(housing['Avg. Area Number of Rooms'], housing['Price'], test_size=0.2, random_state=3500)
x_train = np.reshape(x_train.values, (-1,1))
x_test = np.reshape(x_test.values, (-1,1))
y_train = np.reshape(y_train.values, (-1,1))
y_test = np.reshape(y_test.values, (-1,1))

#
print('Train - Predictors shape', x_train.shape)
print('Test - Predictors shape', x_test.shape)
print('Train - Target shape', y_train.shape)
print('Test - Target shape', y_test.shape)
# Out:
# Train - Predictors shape (4000, 1)
# Test - Predictors shape (1000, 1)
# Train - Target shape (4000, 1)
# Test - Target shape (1000, 1)

# %%
cls = linear_model.LinearRegression()
#Fit method is used for fitting your training data into the model
cls.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = cls.predict(x_test)

# %%
#Parameters used for the model 
cls.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': False,
#  'positive': False}

# %%
print('Co-efficient of linear regression',cls.coef_)
# Out:
# Co-efficient of linear regression [[120464.10357734]]

# %%
print('Intercept of linear regression model',cls.intercept_)
# Out:
# Intercept of linear regression model [393929.59183333]

# %%
print('Mean Square Error', metrics.mean_squared_error(y_test, prediction))
# Out:
# Mean Square Error 111628791146.77057

# %%
print('Model R^2 Square value', metrics.r2_score(y_test, prediction))
# Out:
# Model R^2 Square value 0.0923582017974871

# %%
#Model Regression line on test set
plt.scatter(x_test, y_test)
plt.plot(x_test, prediction, color='red', linewidth=3)
plt.xlabel('Avg. Area Number of Rooms')
plt.ylabel('Price')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %%
sns.jointplot(x=housing['Avg. Area Number of Bedrooms'], y=housing['Price'], data=housing, kind='reg')

# %%
x_train, x_test, y_train, y_test = train_test_split(housing['Avg. Area Number of Bedrooms'], housing['Price'], test_size=0.2, random_state=3500)
x_train = np.reshape(x_train.values, (-1,1))
x_test = np.reshape(x_test.values, (-1,1))
y_train = np.reshape(y_train.values, (-1,1))
y_test = np.reshape(y_test.values, (-1,1))

#
print('Train - Predictors shape', x_train.shape)
print('Test - Predictors shape', x_test.shape)
print('Train - Target shape', y_train.shape)
print('Test - Target shape', y_test.shape)
# Out:
# Train - Predictors shape (4000, 1)
# Test - Predictors shape (1000, 1)
# Train - Target shape (4000, 1)
# Test - Target shape (1000, 1)

# %%
cls = linear_model.LinearRegression()
#Fit method is used for fitting your training data into the model
cls.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = cls.predict(x_test)

# %%
#Parameters used for the model 
cls.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': False,
#  'positive': False}

# %%
print('Co-efficient of linear regression',cls.coef_)
# Out:
# Co-efficient of linear regression [[50715.50938545]]

# %%
print('Intercept of linear regression model',cls.intercept_)
# Out:
# Intercept of linear regression model [1035718.99691477]

# %%
print('Mean Square Error', metrics.mean_squared_error(y_test, prediction))
# Out:
# Mean Square Error 121309612515.05746

# %%
print('Model R^2 Square value', metrics.r2_score(y_test, prediction))
# Out:
# Model R^2 Square value 0.013644475486177421

# %%
#Model Regression line on test set
plt.scatter(x_test, y_test)
plt.plot(x_test, prediction, color='green', linewidth=3)
plt.xlabel('AAvg. Area Number of Bedrooms')
plt.ylabel('Price')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')
